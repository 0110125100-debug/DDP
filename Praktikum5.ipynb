# %% [markdown]
# <a href="https://colab.research.google.com/github/0110125100-debug/DDP/blob/main/Praktikum5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
namakendaraan = "beat"
jeniskendaraan = "motor"
cckendaraan = 200
warnakendaraan = "putih"
rodakendaraan = 2

data_kendaraan = [namakendaraan, jeniskendaraan,
cckendaraan, warnakendaraan, rodakendaraan]

print(data_kendaraan)

hargakendaraan = 8000
tipekendaraan = "metic"

data_kendaraan.append(hargakendaraan)
data_kendaraan.append(tipekendaraan)
print(data_kendaraan)

merekkendaraan = "Honda"
data_kendaraan.insert(2, merekkendaraan)
print(data_kendaraan)
# Out:
# ['beat', 'motor', 200, 'putih', 2]
# ['beat', 'motor', 200, 'putih', 2, 8000, 'metic']
# ['beat', 'motor', 'Honda', 200, 'putih', 2, 8000, 'metic']

# %%
pilihan = int(input("""
silahkan pilih menu yang diinginkan
====================================
1. Luas persegi
2. Luas lingkaran
3. Luas segitiga
====================================
Kirimkan hanya angka saja,
jawaban = """))

match pilihan:
 case 1:
  sisi = int(input("sisi = "))
  luas = sisi * sisi

  print(f"luas persegi dengan {sisi} adalah {luas}")
  #Luas persegi
 case 2:
  #luas lingkaran
  # phi * jari-jari **2
  print("luas lingkaran")
  jarijari = int(input("jarijari = "))
  luas = 3.14 * 3.14

  print(f"luas persegi dengan {sisi} adalah {luas}")
 case 3:
  #luas segitiga
  #(alas * tinggi)/2
  print("")
  alas = int(input("alas : "))
  tinggi = int(input("tinggi : "))
  luas = 0.3 * alas * tinggi

  print(f"luas persegi dengan {sisi} adalah {luas}")
 case _:
  print("maaf salah input data")
# Out:
# silahkan pilih menu yang diinginkan
# ====================================
# 1. Luas persegi
# 2. Luas lingkaran
# 3. Luas segitiga
# ====================================
# Kirimkan hanya angka saja,
# jawaban = 3
#
# alas : 57
# tinggi : 34
# luas persegi dengan 37 adalah 581.4
